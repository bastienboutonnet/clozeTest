# %% [markdown]
# # Cloze Test analysis
# ## From typo corrected file minimal cleanup

# %%
suppressMessages(library(dplyr))
suppressMessages(library(ggplot2))
suppressMessages(library(pastecs))
df=read.csv("./output/allVarsFewMore.csv",header=T,strip.white=TRUE)
head(df)
# Out:
#             subj_id Completion sentID compNoTrail compLower determiner  noun
# 1 R_vrAH2qrxu41QSv7   de trein    143    de trein  de trein         de trein
# 2 R_6Pg4ql6MQumxZo9   de trein    143    de trein  de trein         de trein
# 3 R_1QaBlAsk46HI9NJ   de fiets    143    de fiets  de fiets         de fiets
# 4 R_pKtuHvEeh5mujgl    de auto    143     de auto   de auto         de  auto
# 5 R_RrYmeJDnKB3hv7r   de trein    143    de trein  de trein         de trein
# 6 R_2alPe2ZkILnzWYp   de trein    143    de trein  de trein         de trein
#   isDet isWord NatNess Diff     RT
# 1  True   True       5    6 11.771
# 2  True   True       5    6  2.613
# 3  True   True       5    6  6.412
# 4  True   True       5    6  5.574
# 5  True   True       3    6 10.961
# 6  True   True       4    6 39.432

# %%
nComp=df %>% group_by(sentID) %>% summarise(nComp=length(unique(subj_id))) #merge & derive accurate percentages. On last step
head(nComp)
# Out:
# Source: local data frame [6 x 2]
#
#   sentID nComp
#    (int) (int)
# 1    143    40
# 2    144    40
# 3    145    40
# 4    146    40
# 5    147    40
# 6    148    40

# %%
nComp
# Out:
# Source: local data frame [19 x 2]
#
#    sentID nComp
#     (int) (int)
# 1     143    40
# 2     144    40
# 3     145    40
# 4     146    40
# 5     147    40
# 6     148    40
# 7     149    40
# 8     150    40
# 9     151    40
# 10    152    40
# 11    153    40
# 12    154    40
# 13    155    40
# 14    156    40
# 15    157    40
# 16    158    40
# 17    159    40
# 18    160    40
# 19    161    40

# %%
clozeCounts=df %>% group_by(sentID,compLower) %>% summarise(popularity = length(unique(subj_id))) %>% arrange(desc(popularity)) -> test
clozeCounts=merge(clozeCounts,nComp,by='sentID')
#clozeCounts['percent']=sapply(clozeCounts$popularity, function(x) (x/clozeCounts$nComp)*100)

######IMPORTANT TO RUN THIS.
#otherVars=allVars %>% group_by(sentID) %>% summarise(natNess=mean(NatNess), RT=mean(RT), Diff=mean(Diff))

percentFun <- function(a,b)
{
  return((a/b)*100)
}
clozeCounts['percent']=mapply(percentFun, clozeCounts$popularity,clozeCounts$nComp)
clozeCounts['above70']=sapply(clozeCounts$percent, function(x) if (x>=70) {1} else 0)
head(clozeCounts)
# Out:
#   sentID   compLower popularity nComp percent above70
# 1    143    de trein         32    40    80.0       1
# 2    143     de auto          3    40     7.5       0
# 3    143        auto          1    40     2.5       0
# 4    143      de bus          1    40     2.5       0
# 5    143    de fiets          1    40     2.5       0
# 6    143 de veerboot          1    40     2.5       0

# %%
t=subset(clozeCounts, sentID==148)
t
# Out:
#    sentID         compLower popularity nComp percent above70
# 22    148           de bank         28    40    70.0       1
# 23    148 een spaarrekening          6    40    15.0       0
# 24    148       je rekening          2    40     5.0       0
# 25    148              bank          1    40     2.5       0
# 26    148       de rekening          1    40     2.5       0
# 27    148  een bankrekening          1    40     2.5       0
# 28    148     spaarrekening          1    40     2.5       0

# %%
mostPop=clozeCounts %>% group_by(sentID) %>% filter(popularity == max(popularity))
#mostPop['above70']=sapply(mostPop$percent, function(x) if (x>=70) {1} else 0)
suppressMessages(library(pastecs))
stat.desc(mostPop$above70)
head(mostPop)
# Out:
#      nbr.val     nbr.null       nbr.na          min          max        range
#           19            0            0            1            1            0
#          sum       median         mean      SE.mean CI.mean.0.95          var
#           19            1            1            0            0            0
#      std.dev     coef.var
#            0            0
# Source: local data frame [6 x 6]
# Groups: sentID [6]
#
#   sentID  compLower popularity nComp percent above70
#    (int)     (fctr)      (int) (int)   (dbl)   (dbl)
# 1    143   de trein         32    40    80.0       1
# 2    144 het strand         37    40    92.5       1
# 3    145    de lift         37    40    92.5       1
# 4    146    de auto         32    40    80.0       1
# 5    147 de politie         37    40    92.5       1
# 6    148    de bank         28    40    70.0       1

# %%
above70onlyTemp=subset(mostPop, above70==1)
stat.desc(above70onlyTemp$percent)
# Out:
#      nbr.val     nbr.null       nbr.na          min          max        range
# 1.900000e+01 0.000000e+00 0.000000e+00 7.000000e+01 9.500000e+01 2.500000e+01
#          sum       median         mean      SE.mean CI.mean.0.95          var
# 1.625000e+03 8.750000e+01 8.552632e+01 1.737307e+00 3.649947e+00 5.734649e+01
#      std.dev     coef.var
# 7.572747e+00 8.854288e-02

# %% [markdown]
# ## CleanUp & Frequencies & Merges
# ### Housekeeping

# %%
library(reshape2)
mostPop=transform(mostPop, comp=colsplit(compLower, pattern = " ", names = c('det', 'noun')))
mostPop$comp.det=as.factor(mostPop$comp.det)
head(mostPop)
# Out:
#   sentID  compLower popularity nComp percent above70 comp.det comp.noun
# 1    143   de trein         32    40    80.0       1       de     trein
# 2    144 het strand         37    40    92.5       1      het    strand
# 3    145    de lift         37    40    92.5       1       de      lift
# 4    146    de auto         32    40    80.0       1       de      auto
# 5    147 de politie         37    40    92.5       1       de   politie
# 6    148    de bank         28    40    70.0       1       de      bank

# %%
summary(mostPop[which(mostPop$above70==1),]$comp.det)
# Out:
#  de het
#  13   6

# %%
corpus=read.csv('SUBTLEX-NL_csv.csv')
head(corpus)
# Out:
#   Word FREQcount CDcount FREQlow CDlow FREQlemma SUBTLEXWF Lg10WF SUBTLEXCD
# 1   ik   1744062    8054  778704  3125   1744527  39883.03 6.2416   99.8017
# 2   je   1600888    8060 1315051  6535   1600923  36608.94 6.2044   99.8761
# 3  het   1068396    8066  780771  5578   1913811  24431.97 6.0287   99.9504
# 4   de   1061177    8070  903872  6512   1063827  24266.89 6.0258  100.0000
# 5  dat    965424    8063  715570  6107    965431  22077.22 5.9847   99.9133
# 6   is    947568    8067  891894  7636   1891610  21668.89 5.9766   99.9628
#   Lg10CD
# 1 3.9061
# 2 3.9064
# 3 3.9067
# 4 3.9069
# 5 3.9066
# 6 3.9068

# %%
corpusSub=corpus[,c("Word","Lg10WF")]
mostPopAndFreq=merge(mostPop, corpusSub, by.x='comp.noun',by.y='Word',all.x=T,sort=F)
mostPopAndFreq=mostPopAndFreq[,c('sentID','compLower','popularity','nComp','percent','above70','comp.det','comp.noun','Lg10WF')]
head(mostPopAndFreq)
# Out:
#   sentID  compLower popularity nComp percent above70 comp.det comp.noun Lg10WF
# 1    143   de trein         32    40    80.0       1       de     trein 3.5051
# 2    144 het strand         37    40    92.5       1      het    strand 3.2448
# 3    145    de lift         37    40    92.5       1       de      lift 3.4570
# 4    146    de auto         32    40    80.0       1       de      auto 4.3017
# 5    147 de politie         37    40    92.5       1       de   politie 4.1801
# 6    148    de bank         28    40    70.0       1       de      bank 3.6042

# %%
write.csv(mostPopAndFreq,'mostPopFewMore.csv',row.names=F)

# %% [markdown]
# ### Adding sentences

# %%
origSent=read.csv('../fewMoreQualtrics.csv',header=T)
mostPopFreqSents=merge(origSent, mostPopAndFreq, by='sentID', all.y=T, sort=F)

# %%
head(mostPopFreqSents,2)
# Out:
#   sentID
# 1    143
# 2    144
#                                                                                           SentenceContext
# 1 Auto's and vliegtuigen zijn slecht voor het mileu, dus sommige mensen gaan liever via de Eurotunnel met
# 2                     Er staan lange files voor Zandvoort aan Zee, omdat iedereen lekker wil uitwaaien op
#   sentenceClosure  compLower popularity nComp percent above70 comp.det
# 1  naar Engeland.   de trein         32    40    80.0       1       de
# 2        vandaag. het strand         37    40    92.5       1      het
#   comp.noun Lg10WF
# 1     trein 3.5051
# 2    strand 3.2448

# %% [markdown]
# ### Saving Intermediary Output

# %%
write.csv(mostPopFreqSents,'./output/fewMoreFreqSents.csv',row.names=F)

# %% [markdown]
# # SUMMARISING ALL OTHER VARIABLES
# Todo:
# - for each sentence get summary across participants of **NatNess**, **Diff**, **RT**
# - merge with final sentences (the output with the mostpop and sentence reconstructed and frequency reconstructed).

# %%
fewMoreFreqSents=read.csv('./output/fewMoreFreqSents.csv')
#FOLLOWING STEP HAS TO BE DONE TO ONE OF THE EARLIER BY SUBJECT FILES
otherVarsSumar=df %>% group_by(sentID) %>% summarise(natNess=mean(NatNess), RT=mean(RT), Diff=mean(Diff))
head(otherVarsSumar)
# Out:
# Source: local data frame [6 x 4]
#
#   sentID natNess        RT  Diff
#    (int)   (dbl)     (dbl) (dbl)
# 1    143      NA 11.041300 5.675
# 2    144   4.400  8.278925 5.875
# 3    145   4.275  6.779775 5.700
# 4    146   4.775  5.240100 5.850
# 5    147   4.625  5.952750 5.900
# 6    148      NA  6.976400 5.625

# %%
mostPopAndOtherVar=merge(fewMoreFreqSents,otherVarsSumar,by='sentID',all.x=T)
head(mostPopAndOtherVar)
# Out:
#      nbr.val     nbr.null       nbr.na          min          max        range
# 1.900000e+01 0.000000e+00 0.000000e+00 7.000000e+01 9.500000e+01 2.500000e+01
#          sum       median         mean      SE.mean CI.mean.0.95          var
# 1.625000e+03 8.750000e+01 8.552632e+01 1.737307e+00 3.649947e+00 5.734649e+01
#      std.dev     coef.var
# 7.572747e+00 8.854288e-02

# %%
write.csv(mostPopAndOtherVar,"./output/mostPopAndOtherVarsFewMore.csv",row.names=F)

# %% [markdown]
# ### Frequency Distribution Analaysis

# %%
mostPopFreqSents=read.csv('./output/fewMoreFreqSents.csv',header=T)
mostPopAndFreq70=subset(mostPopFreqSents, above70==1)
mostPopAndFreq70
summary(mostPopAndFreq70)
# Out:
#    sentID
# 1     143
# 2     144
# 3     145
# 4     146
# 5     147
# 6     148
# 7     149
# 8     150
# 9     151
# 10    152
# 11    153
# 12    154
# 13    155
# 14    156
# 15    157
# 16    158
# 17    159
# 18    160
# 19    161
#                                                                                            SentenceContext
# 1  Auto's and vliegtuigen zijn slecht voor het mileu, dus sommige mensen gaan liever via de Eurotunnel met
# 2                      Er staan lange files voor Zandvoort aan Zee, omdat iedereen lekker wil uitwaaien op
# 3                                                                Neem de trap als er brand uitbreekt, want
# 4                                                  Je hebt de bus net gemist, dus ik breng je wel even met
# 5                                            Als je fiets gestolen is, moet je officieel aangifte doen bij
# 6                             Geld sparen in een oude sok is niet meer van deze tijd, je kunt het beter op
# 7      In de Randstad weten veel kinderen minder over de natuur dan mensen die opgroeien in boerderijen op
# 8                                                         Je moet een pak verse melk altijd terugzetten in
# 9                                          Ik heb de borden al op tafel gelegd, kun jij uit de bovenste la
# 10                                                              Mijn hond was ziek dus ik moest ermee naar
# 11                                                             In Mexico zijn drie criminelen ontsnapt uit
# 12                    Als iedereen na de crisis weer meer geld gaat investeren zal het snel beter gaan met
# 13                         Volgens de Sinterklaastraditie in Nederland komt Zwarte Piet vanaf het dak door
# 14                            De overvallers stormden de winkel binnen en gingen direct naar de kassa's om
# 15                                  Ik heb 2 vrijkaartjes voor de bioscoop; het je zin om mee te gaan naar
# 16                                                                 Dit is de hit die je het meest hoort op
# 17                Ik heb geen tuin, want ik woon in een flat, maar ik kan in de zomer wel altijd lekker op
# 18             De koude lucht uit Belgi\314\307 zal zich vanuit het zuiden gaan verspreiden in de rest van
# 19                                                            Op zondag leest mijn vader altijd uitgebreid
#                                sentenceClosure      compLower popularity nComp
# 1                               naar Engeland.       de trein         32    40
# 2                                     vandaag.     het strand         37    40
# 3                           is buiten gebruik.        de lift         37    40
# 4                            naar het station.        de auto         32    40
# 5  om geld terug te krijgen van de verzekering     de politie         37    40
# 6                                      zetten.        de bank         28    40
# 7                               in het oosten. het platteland         32    40
# 8             om te voorkomen dat het bederft.    de koelkast         37    40
# 9                      pakken en erbij leggen?     het bestek         35    40
# 10                                  vanmorgen.  de dierenarts         34    40
# 11                                   gisteren.  de gevangenis         37    40
# 12                               van het land.    de economie         37    40
# 13   het huis binnen om cadeautjes te brengen. de schoorsteen         37    40
# 14                                  te stelen.       het geld         30    40
# 15                              volgende week?        de film         30    40
# 16                               tegenwoordig.       de radio         38    40
# 17                                     zitten.     het balkon         32    40
# 18                                     morgen.       het land         33    40
# 19                            bij het ontbijt.       de krant         35    40
#    percent above70 comp.det   comp.noun Lg10WF
# 1     80.0       1       de       trein 3.5051
# 2     92.5       1      het      strand 3.2448
# 3     92.5       1       de        lift 3.4570
# 4     80.0       1       de        auto 4.3017
# 5     92.5       1       de     politie 4.1801
# 6     70.0       1       de        bank 3.6042
# 7     80.0       1      het  platteland 2.6170
# 8     92.5       1       de    koelkast 2.8116
# 9     87.5       1      het      bestek 1.9542
# 10    85.0       1       de  dierenarts 2.4150
# 11    92.5       1       de  gevangenis 3.6616
# 12    92.5       1       de    economie 2.5658
# 13    92.5       1       de schoorsteen 2.2788
# 14    75.0       1      het        geld 4.5404
# 15    75.0       1       de        film 3.8821
# 16    95.0       1       de       radio 3.4096
# 17    80.0       1      het      balkon 2.4639
# 18    82.5       1      het        land 4.0282
# 19    87.5       1       de       krant 3.4059
#      sentID
#  Min.   :143.0
#  1st Qu.:147.5
#  Median :152.0
#  Mean   :152.0
#  3rd Qu.:156.5
#  Max.   :161.0
#
#                                                                                                 SentenceContext
#  Als iedereen na de crisis weer meer geld gaat investeren zal het snel beter gaan met                   : 1
#  Als je fiets gestolen is, moet je officieel aangifte doen bij                                          : 1
#  Auto's and vliegtuigen zijn slecht voor het mileu, dus sommige mensen gaan liever via de Eurotunnel met: 1
#  De koude lucht uit Belgi<cc><c7> zal zich vanuit het zuiden gaan verspreiden in de rest van            : 1
#  De overvallers stormden de winkel binnen en gingen direct naar de kassa's om                           : 1
#  Dit is de hit die je het meest hoort op                                                                : 1
#  (Other)                                                                                                :13
#                                   sentenceClosure         compLower
#  bij het ontbijt.                         : 1     de auto      : 1
#  gisteren.                                : 1     de bank      : 1
#  het huis binnen om cadeautjes te brengen.: 1     de dierenarts: 1
#  in het oosten.                           : 1     de economie  : 1
#  is buiten gebruik.                       : 1     de film      : 1
#  morgen.                                  : 1     de gevangenis: 1
#  (Other)                                  :13     (Other)      :13
#    popularity        nComp       percent         above70  comp.det
#  Min.   :28.00   Min.   :40   Min.   :70.00   Min.   :1   de :13
#  1st Qu.:32.00   1st Qu.:40   1st Qu.:80.00   1st Qu.:1   het: 6
#  Median :35.00   Median :40   Median :87.50   Median :1
#  Mean   :34.21   Mean   :40   Mean   :85.53   Mean   :1
#  3rd Qu.:37.00   3rd Qu.:40   3rd Qu.:92.50   3rd Qu.:1
#  Max.   :38.00   Max.   :40   Max.   :95.00   Max.   :1
#
#       comp.noun      Lg10WF
#  auto      : 1   Min.   :1.954
#  balkon    : 1   1st Qu.:2.591
#  bank      : 1   Median :3.410
#  bestek    : 1   Mean   :3.280
#  dierenarts: 1   3rd Qu.:3.772
#  economie  : 1   Max.   :4.540
#  (Other)   :13

# %%
options(repr.plot.width = 6)
options(repr.plot.height = 6)
stat.desc(mostPopAndFreq70$Lg10WF)
ggplot(mostPopAndFreq70, aes(x=Lg10WF)) + 
    geom_histogram(aes(y=..density..),binwidth=.3,colour="black", fill="white") +
    geom_density(alpha=.5, fill="#FF6666")+
    geom_rug(alpha=.5)+# Overlay with transparent density plot
    geom_vline(aes(xintercept=mean(Lg10WF, na.rm=T)),color="blue", linetype="solid", size=1)+
    geom_vline(aes(xintercept=median(Lg10WF, na.rm=T)),color="steelblue", linetype="dashed", size=1)
# Out:
#      nbr.val     nbr.null       nbr.na          min          max        range
#   19.0000000    0.0000000    0.0000000    1.9542000    4.5404000    2.5862000
#          sum       median         mean      SE.mean CI.mean.0.95          var
#   62.3270000    3.4096000    3.2803684    0.1716367    0.3605954    0.5597241
#      std.dev     coef.var
#    0.7481471    0.2280680
# plot without title

# %% [markdown]
# ## Save Files

# %%
write.csv(clozeCounts,'./output/clozePossibilitiesForEEG.csv',row.names=F)
write.csv(mostPop,'./output/mostPopForEEG.csv',row.names=F)

# %% [markdown]
# ## SCRAP CODE

# %% [raw]
# #SCRAP CODE
# mostPop=clozeCounts %>% group_by(sentID) %>% filter(popularity == max(popularity))

# %%
stat.desc(mostPop$percent)
ggplot(mostPop, aes(x=percent)) + 
    geom_histogram(aes(y=..density..),      # Histogram with density instead of count on y-axis
                   binwidth=2,
                   colour="black", fill="white") +
    geom_density(alpha=.2, fill="#FF6666")+  # Overlay with transparent density plot
    geom_vline(aes(xintercept=mean(percent, na.rm=T)),color="blue", linetype="dashed", size=1)+
    geom_vline(aes(xintercept=70),color="red", linetype="solid", size=1)
# Out:
#      nbr.val     nbr.null       nbr.na          min          max        range
#   141.000000     0.000000     0.000000    30.612245   100.000000    69.387755
#          sum       median         mean      SE.mean CI.mean.0.95          var
# 10968.319235    82.692308    77.789498     1.576021     3.115878   350.221721
#      std.dev     coef.var
#    18.714212     0.240575
# plot without title

# %%
#tmp=subset(mostPop,above70==1)
stat.desc(tmp$percent)
ggplot(tmp, aes(x=percent)) + 
    geom_histogram(aes(y=..density..),      # Histogram with density instead of count on y-axis
                   binwidth=2,
                   colour="black", fill="white") +
    geom_density(alpha=.2, fill="#FF6666")+  # Overlay with transparent density plot
    geom_vline(aes(xintercept=mean(percent, na.rm=T)),color="blue", linetype="dashed", size=1)+
    geom_vline(aes(xintercept=70),color="red", linetype="solid", size=1)
# Out:
#      nbr.val     nbr.null       nbr.na          min          max        range
#  107.0000000    0.0000000    0.0000000   70.5882353  100.0000000   29.4117647
#          sum       median         mean      SE.mean CI.mean.0.95          var
# 9289.1926667   87.7551020   86.8148847    0.9016679    1.7876442   86.9915264
#      std.dev     coef.var
#    9.3269248    0.1074346
# plot without title
